# %%
import pandas as pd

df1 = pd.read_csv("df_saurabh.csv")
df2 = pd.read_csv("df_mandana.csv")

df_saurabh_mandana = pd.concat([df1, df2], ignore_index=True)

df_saurabh_mandana = df_saurabh_mandana.dropna(axis=1, how="all")

df_saurabh_mandana

df_saurabh_mandana.to_csv(r"D:\04_IronHack_DA\IRONHACK_LABS_PROJECTS\Shark-Attack\df_saurabh_mandana.csv", index=False)

# %%
df_saurabh_mandana
# Out:
#          Date  Year        Type        Country  \
# 0      18-Mar  2026  Unprovoked            usa
# 1      14-Mar  2026  Unprovoked      australia
# 2      10-Mar  2026  Unprovoked      australia
# 3      05-Mar  2026  Unprovoked      australia
# 4      22-Feb  2026  Unprovoked  new caledonia
# ...       ...   ...         ...            ...
# 11072     NaN   NaN         NaN            NaN
# 11073     NaN   NaN         NaN            NaN
# 11074     NaN   NaN         NaN            NaN
# 11075     NaN   NaN         NaN            NaN
# 11076     NaN   NaN         NaN            NaN
#
#                                                   Source Activity  \
# 0       us sun: mendocino coast news:melissa michaelson:      NaN
# 1      people magazine: kevin mcmurray trackingsharks...      NaN
# 2           perth now: kevin mcmurray trackingsharks.com      NaN
# 3                     news.com.au: abc news: andy currie      NaN
# ...
